# %% [markdown]
# # **Task C2**
# ## Plotting the Avocado Data using Pandas and Seaborn
#
# ##### This task uses the avocado dataset. The dataset contains historical data on avocado prices and sales volume in multiple U.S. markets. One of the columns in this dataset, Unnamed: 0, contains sequential numbers that are irrelevant to analyzing this data. Three of the other columns contain sales for PLU (price look-up) codes 4046, 4225, and 4770. These columns will not be used in this task. If you review the data, you’ll see that some of the regions overlap. For example, one of the regions is the entire U.S., and all of the other regions are parts of the U.S. Because of that, you would need to review this data carefully before determining the best way to analyze it. For the purposes of this task though, the overlapping regions won’t be taken into consideration.
#
# ##### https://www.kaggle.com/neuromusic/avocado-prices
#
# <img src="avocado-logo.png" alt="SIT112 Avocado!" width="1800" height="200">

# %% [markdown]
# ### A. Instructions
#
# 1. Make sure you have completed Task P3 before working on this task.
# 2. Complete the task based on the comments and hints provided in the following sections.
# 3. Complete the TaskCompletionReport from.
# 4. Before submission, please make sure you have executed all the cells in your jupyter notebook without any error; otherwise, your submission may not be flagged as complete.
# 5. Submit (1) the TaskCompletionReport as a "PDF" file and (2) your solution (code) as an "ipynb" file (do not zip/combine them). You can do this by the end of Week 12, but feedback will only be provided for submissions received by 11 AM on the due date. <font color="red">Please do not include the dataset in your submission. </font>
# 6. The workshops are the primary venue for you to seek help if you need any clarification/assistance. The tutors are there to help you complete and submit the tasks. Please avoid emailing your code or screenshots to the tutors outside workshop hours.
# 7. Consider using online resources such as ChatGPT to strengthen your undertanding of the task.
#
# Good luck :)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### B. Write Python code that performs (answers) the following operations (questions)

# %% [markdown]
# ##### 1. Read the data from the .csv file into a DataFrame and display the first five rows.

# %%
# write your code here
data = pd.read_csv('avocado.csv')
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %% [markdown]
# ##### 2. Filter the data to exclude the following regions: TotalUS, West, and NorthEast. Use the filtered data to create a DataFrame that contains the total of the Small Bags, Large Bags, and XLarge Bags columns grouped by type. Use the grouped data to create a bar plot that shows the number of small, large, and extra-large bags for both types of avocado. Set the tile and axis labels of the bar plot and make sure all the labels are readable.

# %%
# write your code here

# Filter the data to exclude the specified regions
excluded_regions = ['TotalUS', 'West', 'NorthEast']
filtered_data = data[~data['region'].isin(excluded_regions)]

# Group the filtered data by type and calculate the total number of small, large, and extra-large bags
grouped_data = filtered_data.groupby('type').sum()[['Small Bags', 'Large Bags', 'XLarge Bags']]


# Create a bar plot using the grouped data
ax = grouped_data.plot.bar()

# Set the title and axis labels with appropriate padding
ax.set_title('Total Number of Small, Large, and XLarge Bags by Avocado Type', pad=10)
ax.set_xlabel('Avocado Type')
ax.set_ylabel('Number of Bags')

# # Display the plot
# plt.show()

# import seaborn as sns
# import matplotlib.pyplot as plt

# # Filter the data to exclude the specified regions
# excluded_regions = ['TotalUS', 'West', 'NorthEast']
# filtered_data = data[~data['region'].isin(excluded_regions)]

# # Group the filtered data by type and calculate the total number of small, large, and extra-large bags
# grouped_data = filtered_data.groupby('type').sum()[['Small Bags', 'Large Bags', 'XLarge Bags']]

# # Reset the index of the grouped data
# grouped_data = grouped_data.reset_index()

# # Melt the grouped data to create a long-form dataframe
# melted_data = pd.melt(grouped_data, id_vars=['type'], var_name='Bag Size', value_name='Number of Bags')

# # Create a bar plot using seaborn
# sns.barplot(x='type', y='Number of Bags', hue='Bag Size', data=melted_data)

# # Set the title and axis labels with appropriate padding
# plt.title('Total Number of Small, Large, and XLarge Bags by Avocado Type', pad=10)
# plt.xlabel('Avocado Type')
# plt.ylabel('Number of Bags')

# # Display the plot
# plt.show()
# Out:
# Text(0, 0.5, 'Number of Bags')

# %% [markdown]
# ##### 3. Analyze the avocado data from 2016 to 2018, to identify the top six regions where the sum of the average price of avocados is the highest. Create a visualization containing a grid of subplots, where each subplot is a box plot showing the distribution of average prices of organic and conventional avocados from 2016 to 2018, for the top six regions identified.

# %%
# Filter the data to include only years 2016 to 2018
data_filtered = data[(data['year']>= 2016) & (data['year']<=2018)]

# Group the filtered data by region and calculate the sum of average prices for each group
region_price = data_filtered.groupby(['region'])['AveragePrice'].agg(['sum']).rename(columns={'sum':'AveragePriceSum'})

# Select the top 6 regions with the highest sum of average prices
top_regions = region_price.nlargest(6, 'AveragePriceSum').index.get_level_values(0)

# Filter the data to include only the top 6 regions
data_top = data[(data['region'].isin(top_regions))]

# Create separate dataframes for organic and conventional avocados in the top 6 regions
organic_avocado_df = data_top[data_top['type'] == 'organic']
conventional_avocado_df = data_top[data_top['type'] == 'conventional']

# Create a 3x2 grid of subplots and flatten it into a 1D array of axes
fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(16, 9))
axs = axs.flatten()


# For each of the top 6 regions, create a box plot of the distribution of average prices for organic and conventional avocados
for i, region in enumerate(top_regions):
    if i < len(axs):
        organic_region_df = organic_avocado_df[organic_avocado_df['region'] == region]
        conventional_region_df = conventional_avocado_df[conventional_avocado_df['region'] == region]
        
        region_df = pd.concat([organic_region_df['AveragePrice'], conventional_region_df['AveragePrice']], axis=1)
        region_df.columns = ['Organic', 'Conventional']
        
        region_df.plot(kind='box', ax=axs[i], title=region)
        axs[0].set_ylabel('Price')
        
# Adjust the layout of the subplots to reduce overlap and show the plot
plt.tight_layout()
plt.show()

# # Filter the data to include only years 2016 to 2018
# data_filtered = data[(data['year']>= 2016) & (data['year']<=2018)]

# # Group the filtered data by region and calculate the sum of average prices for each group
# region_price = data_filtered.groupby(['region'])['AveragePrice'].agg(['sum']).rename(columns={'sum':'AveragePriceSum'})

# # Select the top 6 regions with the highest sum of average prices
# top_regions = region_price.nlargest(6, 'AveragePriceSum').index.get_level_values(0)

# # Create a 3x2 grid of subplots and flatten it into a 1D array of axes
# fig, axs = plt.subplots(nrows=3, ncols=2, figsize=(16, 9))
# axs = axs.flatten()

# # For each of the top 6 regions, create a box plot of the distribution of average prices for organic and conventional avocados
# for i, region in enumerate(top_regions):
#     if i < len(axs):
#         # Filter the data to include only the current region
#         region_data = data_filtered[data_filtered['region'] == region]
        
#         # Create separate dataframes for organic and conventional avocados in the current region
#         organic_avocado_df = region_data[region_data['type'] == 'organic']
#         conventional_avocado_df = region_data[region_data['type'] == 'conventional']
        
#         # Combine the dataframes into a single dataframe for plotting
#         region_df = pd.concat([organic_avocado_df['AveragePrice'], conventional_avocado_df['AveragePrice']], axis=1)
#         region_df.columns = ['Organic', 'Conventional']
        
#         # Create a box plot of the distribution of average prices for organic and conventional avocados in the current region
#         region_df.plot(kind='box', ax=axs[i], title=region)
#         axs[0].set_ylabel('Price')
        
# # Adjust the layout of the subplots to reduce overlap and show the plot
# plt.tight_layout()
# plt.show()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 11310           0  2015-12-27          1.88      14081.58    792.47  13036.76
# 11311           1  2015-12-20          1.87      13703.79    980.71  12582.57
# 11312           2  2015-12-13          1.94      13713.65   1379.97  12152.10
# 11313           3  2015-12-06          1.92      15144.79   1663.88  13355.31
# 11314           4  2015-11-29          2.58      13218.02    953.12  12235.08
# ...           ...         ...           ...           ...       ...       ...
# 18112           7  2018-02-04          1.34      28070.07  13610.05  12257.81
# 18113           8  2018-01-28          2.27      20325.75   9368.06   8808.80
# 18114           9  2018-01-21          1.36      27919.45  13037.67  11998.44
# 18115          10  2018-01-14          1.32      37347.89  19301.15  14957.23
# 18116          11  2018-01-07          2.30      20151.24  10165.34   8042.56
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 11310   0.0      252.35      252.35        0.00          0.0  organic  2015
# 11311   0.0      140.51      140.51        0.00          0.0  organic  2015
# 11312   0.0      181.58      181.58        0.00          0.0  organic  2015
# 11313   0.0      125.60      125.60        0.00          0.0  organic  2015
# 11314   0.0       29.82        3.15       26.67          0.0  organic  2015
# ...     ...         ...         ...         ...          ...      ...   ...
# 18112   0.0     2202.21     2202.21        0.00          0.0  organic  2018
# 18113   0.0     2148.89     2148.89        0.00          0.0  organic  2018
# 18114   0.0     2883.34     2883.34        0.00          0.0  organic  2018
# 18115   0.0     3089.51     3089.51        0.00          0.0  organic  2018
# 18116   0.0     1943.34     1943.34        0.00          0.0  organic  2018
#
#              region
# 11310  SanFrancisco
# 11311  SanFrancisco
# 11312  SanFrancisco
# 11313  SanFrancisco
# 11314  SanFrancisco
# ...             ...
# 18112  SanFrancisco
# 18113  SanFrancisco
# 18114  SanFrancisco
# 18115  SanFrancisco
# 18116  SanFrancisco
#
# [169 rows x 14 columns]
#        Unnamed: 0        Date  AveragePrice  Total Volume    4046      4225  \
# 10010           0  2015-12-27          2.32       5526.50   88.59   3733.01
# 10011           1  2015-12-20          2.24       3998.59  222.69   1874.44
# 10012           2  2015-12-13          2.34       6923.91   75.32   2154.16
# 10013           3  2015-12-06          2.16       2739.09  192.25   2179.25
# 10014           4  2015-11-29          2.33       1632.72   30.30   1476.57
# ...           ...         ...           ...           ...     ...       ...
# 17812           7  2018-02-04          1.94      17404.84  142.97   8510.44
# 17813           8  2018-01-28          1.90      18973.89  468.61  10161.69
# 17814           9  2018-01-21          2.12      12308.98   97.64   4096.79
# 17815          10  2018-01-14          2.02      14448.86  122.85   4410.11
# 17816          11  2018-01-07          2.03      15204.66   76.07   4721.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  \
# 10010     6.81     1698.09     1619.34       78.75          0.0  organic
# 10011   230.89     1670.57     1670.57        0.00          0.0  organic
# 10012  2410.25     2284.18     2284.18        0.00          0.0  organic
# 10013    15.11      352.48      349.15        3.33          0.0  organic
# 10014     0.00      125.85       89.73       36.12          0.0  organic
# ...        ...         ...         ...         ...          ...      ...
# 17812    15.34     8736.09     8736.09        0.00          0.0  organic
# 17813     2.79     8340.80     8340.80        0.00          0.0  organic
# 17814     1.39     8113.16     8079.06       34.10          0.0  organic
# 17815     0.00     9915.90     9911.02        4.88          0.0  organic
# 17816     1.40    10405.77    10405.77        0.00          0.0  organic
#
#        year               region
# 10010  2015  HartfordSpringfield
# 10011  2015  HartfordSpringfield
# 10012  2015  HartfordSpringfield
# 10013  2015  HartfordSpringfield
# 10014  2015  HartfordSpringfield
# ...     ...                  ...
# 17812  2018  HartfordSpringfield
# 17813  2018  HartfordSpringfield
# 17814  2018  HartfordSpringfield
# 17815  2018  HartfordSpringfield
# 17816  2018  HartfordSpringfield
#
# [169 rows x 14 columns]
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 10582           0  2015-12-27          1.90      21565.58   1752.06   6546.95
# 10583           1  2015-12-20          1.93      24549.47   3571.41  11118.88
# 10584           2  2015-12-13          1.90      23927.09   2764.18   6739.98
# 10585           3  2015-12-06          1.65      18494.23   4117.08   7226.46
# 10586           4  2015-11-29          1.89       9962.63   1481.23   4689.04
# ...           ...         ...           ...           ...       ...       ...
# 17944           7  2018-02-04          1.83      93204.08   9300.64  21428.22
# 17945           8  2018-01-28          1.75      96380.28  13196.30  24933.01
# 17946           9  2018-01-21          1.91      71760.69   5732.09  13124.59
# 17947          10  2018-01-14          1.91      86632.25   7433.43  17885.26
# 17948          11  2018-01-07          1.97      82637.97   6158.73  19251.81
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  \
# 10582  1319.02    11947.55     5757.79     6189.76          0.0  organic
# 10583  1760.45     8098.73     7057.10     1041.63          0.0  organic
# 10584  4130.01    10292.92     7553.74     2739.18          0.0  organic
# 10585  1106.58     6044.11      200.30     5843.81          0.0  organic
# 10586   807.44     2984.92      336.18     2648.74          0.0  organic
# ...        ...         ...         ...         ...          ...      ...
# 17944   814.47    61660.75    61516.19      144.56          0.0  organic
# 17945   128.24    58122.73    56090.23     2032.50          0.0  organic
# 17946   157.72    52746.29    52130.98      615.31          0.0  organic
# 17947    49.43    61264.13    60763.71      500.42          0.0  organic
# 17948    47.04    57180.39    57180.39        0.00          0.0  organic
#
#        year   region
# 10582  2015  NewYork
# 10583  2015  NewYork
# 10584  2015  NewYork
# 10585  2015  NewYork
# 10586  2015  NewYork
# ...     ...      ...
# 17944  2018  NewYork
# 17945  2018  NewYork
# 17946  2018  NewYork
# 17947  2018  NewYork
# 17948  2018  NewYork
#
# [169 rows x 14 columns]
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 11206           0  2015-12-27          1.72       4946.40  1142.95  3722.48
# 11207           1  2015-12-20          1.68       5161.57  1124.17  3959.43
# 11208           2  2015-12-13          1.68       5141.65  1171.12  3811.97
# 11209           3  2015-12-06          1.43       7422.92  1835.84  4810.97
# 11210           4  2015-11-29          2.04       4643.81   872.55  3592.50
# ...           ...         ...           ...           ...      ...      ...
# 18088           7  2018-02-04          1.50       8713.26  2722.60  4194.00
# 18089           8  2018-01-28          1.99       7631.73  2280.40  3098.00
# 18090           9  2018-01-21          1.62       8933.22  3017.16  3954.94
# 18091          10  2018-01-14          1.60       9939.69  3653.04  4484.42
# 18092          11  2018-01-07          2.18       6511.97  2187.59  2577.71
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 11206   0.0       80.97       80.97        0.00          0.0  organic  2015
# 11207   0.0       77.97       77.97        0.00          0.0  organic  2015
# 11208   0.0      158.56      158.56        0.00          0.0  organic  2015
# 11209   0.0      776.11      762.78       13.33          0.0  organic  2015
# 11210   0.0      178.76      112.09       66.67          0.0  organic  2015
# ...     ...         ...         ...         ...          ...      ...   ...
# 18088   0.0     1796.66     1796.66        0.00          0.0  organic  2018
# 18089   0.0     2253.33     2253.33        0.00          0.0  organic  2018
# 18090   0.0     1961.12     1961.12        0.00          0.0  organic  2018
# 18091   0.0     1802.23     1802.23        0.00          0.0  organic  2018
# 18092   0.0     1746.67     1746.67        0.00          0.0  organic  2018
#
#            region
# 11206  Sacramento
# 11207  Sacramento
# 11208  Sacramento
# 11209  Sacramento
# 11210  Sacramento
# ...           ...
# 18088  Sacramento
# 18089  Sacramento
# 18090  Sacramento
# 18091  Sacramento
# 18092  Sacramento
#
# [169 rows x 14 columns]
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 10790           0  2015-12-27          1.50       8780.15   340.10  2365.13
# 10791           1  2015-12-20          1.83       6900.94   719.56  2853.84
# 10792           2  2015-12-13          1.79       7292.08   256.60  1559.27
# 10793           3  2015-12-06          1.35       7324.92   482.30  1520.73
# 10794           4  2015-11-29          1.45       5104.74   257.73  1325.46
# ...           ...         ...           ...           ...      ...      ...
# 17992           7  2018-02-04          1.63      27035.57  2687.03  3164.38
# 17993           8  2018-01-28          1.61      28257.18  3878.22  3721.44
# 17994           9  2018-01-21          1.73      23115.66  2121.11  2654.73
# 17995          10  2018-01-14          1.63      30339.71  2315.82  3563.73
# 17996          11  2018-01-07          1.69      27971.66  1954.92  3857.27
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 10790    3.71     6071.21      560.04     5511.17          0.0  organic  2015
# 10791  522.00     2805.54     1195.09     1610.45          0.0  organic  2015
# 10792  952.44     4523.77     1098.51     3425.26          0.0  organic  2015
# 10793   23.75     5298.14       64.68     5233.46          0.0  organic  2015
# 10794    5.99     3515.56      102.78     3412.78          0.0  organic  2015
# ...       ...         ...         ...         ...          ...      ...   ...
# 17992   20.63    21163.53    21162.15        1.38          0.0  organic  2018
# 17993    7.64    20649.88    20602.87       47.01          0.0  organic  2018
# 17994    3.61    18336.21    18326.57        9.64          0.0  organic  2018
# 17995    8.40    24451.76    24402.26       49.50          0.0  organic  2018
# 17996    0.00    22159.47    22155.03        4.44          0.0  organic  2018
#
#              region
# 10790  Philadelphia
# 10791  Philadelphia
# 10792  Philadelphia
# 10793  Philadelphia
# 10794  Philadelphia
# ...             ...
# 17992  Philadelphia
# 17993  Philadelphia
# 17994  Philadelphia
# 17995  Philadelphia
# 17996  Philadelphia
#
# [169 rows x 14 columns]
#        Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 10634           0  2015-12-27          1.70      75884.69   2608.86  15574.88
# 10635           1  2015-12-20          1.77      73826.41   5825.64  17999.10
# 10636           2  2015-12-13          1.80      76466.85   3310.22  12755.23
# 10637           3  2015-12-06          1.53      67245.25   5884.58  13280.16
# 10638           4  2015-11-29          1.59      48901.36   2430.46   9533.76
# ...           ...         ...           ...           ...       ...       ...
# 17956           7  2018-02-04          1.66     273309.58  16597.29  41306.63
# 17957           8  2018-01-28          1.56     319174.35  23903.56  45738.71
# 17958           9  2018-01-21          1.75     215742.94  11683.16  26922.85
# 17959          10  2018-01-14          1.67     272690.13  14282.25  33534.86
# 17960          11  2018-01-07          1.75     264448.77  11605.47  35898.69
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  \
# 10634  1202.38    56498.57    34774.94    21723.63          0.0  organic
# 10635  2401.24    47600.43    40812.08     6788.35          0.0  organic
# 10636  7637.49    52763.91    37344.72    15419.19          0.0  organic
# 10637   961.10    47119.41    29475.97    17643.44          0.0  organic
# 10638   710.99    36226.15    24764.03    11462.12          0.0  organic
# ...        ...         ...         ...         ...          ...      ...
# 17956   766.14   214639.52   188630.21    26009.31          0.0  organic
# 17957   143.80   249388.28   242631.48     6756.80          0.0  organic
# 17958   162.73   176974.20   167900.81     9073.39          0.0  organic
# 17959    58.59   224814.43   206708.26    18106.17          0.0  organic
# 17960    55.76   216888.85   205469.10    11419.75          0.0  organic
#
#        year     region
# 10634  2015  Northeast
# 10635  2015  Northeast
# 10636  2015  Northeast
# 10637  2015  Northeast
# 10638  2015  Northeast
# ...     ...        ...
# 17956  2018  Northeast
# 17957  2018  Northeast
# 17958  2018  Northeast
# 17959  2018  Northeast
# 17960  2018  Northeast
#
# [169 rows x 14 columns]

# %% [markdown]
# ### C. Learn more
#
# * https://www.youtube.com/watch?v=jb_MvVFZXeU
# * https://seaborn.pydata.org/examples/index.html
# * https://matplotlib.org/stable/gallery/index.html
# * https://plotly.com/python/
# * https://www.kaggle.com/code/kanncaa1/plotly-tutorial-for-beginners
