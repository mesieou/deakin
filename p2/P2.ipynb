# %% [markdown]
# # **Task P2**
# ## Analyzing the Avocado Data
# ##### This task uses the avocado dataset. The dataset contains historical data on avocado prices and sales volume in multiple U.S. markets. One of the columns in this dataset, Unnamed: 0, contains sequential numbers that are irrelevant to analyzing this data. Three of the other columns contain sales for PLU (price look-up) codes 4046, 4225, and 4770. These columns will not be used in this task. If you review the data, you’ll see that some of the regions overlap. For example, one of the regions is the entire U.S., and all of the other regions are parts of the U.S. Because of that, you would need to review this data carefully before determining the best way to analyze it. For the purposes of this task though, the overlapping regions won’t be taken into consideration.
#
# ##### https://www.kaggle.com/neuromusic/avocado-prices
#
# <img src="avocado-logo.png" alt="SIT112 Avocado!" width="1800" height="200">

# %% [markdown]
# ### A. Instructions
#
# 1. Complete this task without looking at the solution notebook.
# 2. You can then look at the solution notebook and compare it against yours.
# 3. Complete and submit the TaskCompletionReport form in PDF format using Ontrack. You can do this by the end of Week 12, but feedback will only be provided for submissions received by 11 AM of the due date.
# 4. Do **not** include the solution (yours or the one provided to you) in your submission.
# 5. The workshops are the primary venue for you to seek help if you need any clarification/assitance. The tutors are there to help you complete and submit the tasks. Please avoid emailing your code or screenshots to the tutors outside workshop hours.
# 6. Consider using online resources such as ChatGPT to strenghten your undertanding of the task.
#
# Good luck :)

# %% [markdown]
# ### B. Write Python code that performs (answers) the following operations (questions)

# %%
# Import the pandas library and alias it as "pd"
import pandas as pd

# %% [markdown]
# ##### 1. Read the data from the CSV file into a DataFrame.

# %%
# write your code here

# Read the csv file 'avocado.csv' and store it in a variable called 'data'
data = pd.read_csv('avocado.csv')
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %% [markdown]
# ##### 2. Display type, memory consumption, and null count information using the info() method.

# %%
# write your code here
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB
# None

# %% [markdown]
# ##### 3. Display the number of unique values in each column.

# %%
# write your code here
data.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# ##### 4. Display all the rows of data that JupyterLab displays by default.

# %%
# write your code here
data.head(30)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0            0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1            1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2            2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3            3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4            4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5            5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6            6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7            7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8            8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9            9  2015-10-25          1.07      74338.76   842.40   64757.44
# 10          10  2015-10-18          1.12      84843.44   924.86   75595.85
# 11          11  2015-10-11          1.28      64489.17  1582.03   52677.92
# 12          12  2015-10-04          1.31      61007.10  2268.32   49880.67
# 13          13  2015-09-27          0.99     106803.39  1204.88   99409.21
# 14          14  2015-09-20          1.33      69759.01  1028.03   59313.12
# 15          15  2015-09-13          1.28      76111.27   985.73   65696.86
# 16          16  2015-09-06          1.11      99172.96   879.45   90062.62
# 17          17  2015-08-30          1.07     105693.84   689.01   94362.67
# 18          18  2015-08-23          1.34      79992.09   733.16   67933.79
# 19          19  2015-08-16          1.33      80043.78   539.65   68666.01
# 20          20  2015-08-09          1.12     111140.93   584.63  100961.46
# 21          21  2015-08-02          1.45      75133.10   509.94   62035.06
# 22          22  2015-07-26          1.11     106757.10   648.75   91949.05
# 23          23  2015-07-19          1.26      96617.00  1042.10   82049.40
# 24          24  2015-07-12          1.05     124055.31   672.25   94693.52
# 25          25  2015-07-05          1.35     109252.12   869.45   72600.55
# 26          26  2015-06-28          1.37      89534.81   664.23   57545.79
# 27          27  2015-06-21          1.27     104849.39   804.01   76688.55
# 28          28  2015-06-14          1.32      89631.30   850.58   55400.94
# 29          29  2015-06-07          1.07     122743.06   656.71   99220.82
#
#        4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0     48.16     8696.87     8603.62       93.25         0.00  conventional
# 1     58.33     9505.56     9408.07       97.49         0.00  conventional
# 2    130.50     8145.35     8042.21      103.14         0.00  conventional
# 3     72.58     5811.16     5677.40      133.76         0.00  conventional
# 4     75.78     6183.95     5986.26      197.69         0.00  conventional
# 5     43.61     6683.91     6556.47      127.44         0.00  conventional
# 6     93.26     8318.86     8196.81      122.05         0.00  conventional
# 7     80.00     6829.22     6266.85      562.37         0.00  conventional
# 8     85.34    11388.36    11104.53      283.83         0.00  conventional
# 9    113.00     8625.92     8061.47      564.45         0.00  conventional
# 10   117.07     8205.66     7877.86      327.80         0.00  conventional
# 11   105.32    10123.90     9866.27      257.63         0.00  conventional
# 12   101.36     8756.75     8379.98      376.77         0.00  conventional
# 13   154.84     6034.46     5888.87      145.59         0.00  conventional
# 14   150.50     9267.36     8489.10      778.26         0.00  conventional
# 15   142.00     9286.68     8665.19      621.49         0.00  conventional
# 16   240.79     7990.10     7762.87      227.23         0.00  conventional
# 17   335.43    10306.73    10218.93       87.80         0.00  conventional
# 18   444.78    10880.36    10745.79      134.57         0.00  conventional
# 19   394.90    10443.22    10297.68      145.54         0.00  conventional
# 20   368.95     9225.89     9116.34      109.55         0.00  conventional
# 21   741.08    11847.02    11768.52       78.50         0.00  conventional
# 22   966.61    13192.69    13061.53      131.16         0.00  conventional
# 23  2238.02    11287.48    11103.49      183.99         0.00  conventional
# 24  4257.64    24431.90    24290.08      108.49        33.33  conventional
# 25  5883.16    29898.96    29663.19      235.77         0.00  conventional
# 26  4662.71    26662.08    26311.76      350.32         0.00  conventional
# 27  5481.18    21875.65    21662.00      213.65         0.00  conventional
# 28  4377.19    29002.59    28343.14      659.45         0.00  conventional
# 29    90.32    22775.21    22314.99      460.22         0.00  conventional
#
#     year  region
# 0   2015  Albany
# 1   2015  Albany
# 2   2015  Albany
# 3   2015  Albany
# 4   2015  Albany
# 5   2015  Albany
# 6   2015  Albany
# 7   2015  Albany
# 8   2015  Albany
# 9   2015  Albany
# 10  2015  Albany
# 11  2015  Albany
# 12  2015  Albany
# 13  2015  Albany
# 14  2015  Albany
# 15  2015  Albany
# 16  2015  Albany
# 17  2015  Albany
# 18  2015  Albany
# 19  2015  Albany
# 20  2015  Albany
# 21  2015  Albany
# 22  2015  Albany
# 23  2015  Albany
# 24  2015  Albany
# 25  2015  Albany
# 26  2015  Albany
# 27  2015  Albany
# 28  2015  Albany
# 29  2015  Albany

# %% [markdown]
# ##### 5. Display the first and last five rows of data and the first and last four columns of data.

# %%
# write your code here
pd.concat([data.head(5),data.tail(5)])

pd.concat([data.iloc[0:, :4], data.iloc[0:, -4:]], axis=1)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume  XLarge Bags  \
# 0               0  2015-12-27          1.33      64236.62          0.0
# 1               1  2015-12-20          1.35      54876.98          0.0
# 2               2  2015-12-13          0.93     118220.22          0.0
# 3               3  2015-12-06          1.08      78992.15          0.0
# 4               4  2015-11-29          1.28      51039.60          0.0
# ...           ...         ...           ...           ...          ...
# 18244           7  2018-02-04          1.63      17074.83          0.0
# 18245           8  2018-01-28          1.71      13888.04          0.0
# 18246           9  2018-01-21          1.87      13766.76          0.0
# 18247          10  2018-01-14          1.93      16205.22          0.0
# 18248          11  2018-01-07          1.62      17489.58          0.0
#
#                type  year            region
# 0      conventional  2015            Albany
# 1      conventional  2015            Albany
# 2      conventional  2015            Albany
# 3      conventional  2015            Albany
# 4      conventional  2015            Albany
# ...             ...   ...               ...
# 18244       organic  2018  WestTexNewMexico
# 18245       organic  2018  WestTexNewMexico
# 18246       organic  2018  WestTexNewMexico
# 18247       organic  2018  WestTexNewMexico
# 18248       organic  2018  WestTexNewMexico
#
# [18249 rows x 8 columns]

# %% [markdown]
# ##### 6. Choose any three columns, access them with bracket notation, and display the first five rows of this data.

# %%
# write your code here
data.loc[:5,"Date":"Total Volume"]
# Out:
#          Date  AveragePrice  Total Volume
# 0  2015-12-27          1.33      64236.62
# 1  2015-12-20          1.35      54876.98
# 2  2015-12-13          0.93     118220.22
# 3  2015-12-06          1.08      78992.15
# 4  2015-11-29          1.28      51039.60
# 5  2015-11-22          1.26      55979.78

# %% [markdown]
# ##### 7. Select one column and access it with dot notation.

# %%
# write your code here
data.Date
# Out:
# 0        2015-12-27
# 1        2015-12-20
# 2        2015-12-13
# 3        2015-12-06
# 4        2015-11-29
#             ...
# 18244    2018-02-04
# 18245    2018-01-28
# 18246    2018-01-21
# 18247    2018-01-14
# 18248    2018-01-07
# Name: Date, Length: 18249, dtype: object

# %% [markdown]
# ##### 8. Multiply the Total Volume and AveragePrice columns, and store the result in a new column called EstimatedRevenue. Then, display the first five rows of this data to confirm that the column was added and has the correct values.

# %%
# write your code here
data["EstimatedRevenue"] = data["Total Volume"] * data["AveragePrice"]
data.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region  EstimatedRevenue
# 0  2015  Albany        85434.7046
# 1  2015  Albany        74083.9230
# 2  2015  Albany       109944.8046
# 3  2015  Albany        85311.5220
# 4  2015  Albany        65330.6880

# %% [markdown]
# ##### 9. Create a DataFrame that’s grouped by region and type and that includes the average price for the grouped columns. Then, reset the index and display the first five rows.

# %%
# write your code here
grouped_data = data.groupby(["region", "type"])["AveragePrice"].mean().reset_index()
grouped_data.head(5)
# Out:
#                 region          type  AveragePrice
# 0               Albany  conventional      1.348757
# 1               Albany       organic      1.773314
# 2              Atlanta  conventional      1.068817
# 3              Atlanta       organic      1.607101
# 4  BaltimoreWashington  conventional      1.344201

# %% [markdown]
# ##### 10. Create a bar plot that shows the mean, median, and standard deviation of the Total Volume column by year.

# %%
# write your code here
import matplotlib.pyplot as plt
stats = data.groupby("year")["Total Volume"].agg(['mean', 'median', 'std']).reset_index()

plt.figure(figsize=(12,6))
plt.bar(stats["year"] - 0.25, stats["mean"], width=0.25, label="Mean")
plt.bar(stats["year"], stats["median"], width=0.25, label="Median")
plt.bar(stats["year"] + 0.25, stats["std"], width=0.25, label="Standard Deviation")

plt.xlabel("year")
plt.ylabel("Total Volume")
plt.title("Mean, Median and Standard Deviation of Total Volume by Year")
plt.xticks(stats['year'])
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 11. How many unique regions are there?

# %%
# write your code here
data.region.nunique()
# Out:
# 54

# %% [markdown]
# ##### 12. What is the average price for each type of avocado (organic and conventional)? Be sure to include just the type and AveragePrice columns in the results.

# %%
# write your code here
data.groupby('type')["AveragePrice"].mean().reset_index()
# Out:
#            type  AveragePrice
# 0  conventional      1.158040
# 1       organic      1.653999

# %% [markdown]
# ##### 13. Which region has the lowest average price for organic avocados? Hint: create wide data from the grouped data that you created in section B.9.

# %%
# write your code here

# Group the data by region and type, calculate the mean AveragePrice,
grouped_data = data.groupby(['region', 'type'])['AveragePrice'].mean().reset_index()
# and then pivot the table to show the AveragePrice by region and type.
grouped_data.head()
# pivoted_table = grouped_data.pivot(index="region", columns="type", values="AveragePrice")
# # then sort the table by organic AveragePrice in ascending order and
# sorted_pivoted_table = pivoted_table.sort_values(by="organic", ascending=True)
# # display the row with the lowest organic AveragePrice.
# sorted_pivoted_table.head()
# Out:
#                 region          type  AveragePrice
# 0               Albany  conventional      1.348757
# 1               Albany       organic      1.773314
# 2              Atlanta  conventional      1.068817
# 3              Atlanta       organic      1.607101
# 4  BaltimoreWashington  conventional      1.344201

# %% [markdown]
# ##### 14. Have the Total Bags sold per year of each type of avocado become more or less consistent over time?
#
# #####  *Use the standard deviation (std), which is a statistical measure of how spread out the data is from the mean. In this case, using std to analyze the Total Bags sold per year of each type of avocado can help us understand how consistent the sales are over time: If the std is high, it means that the Total Bags sold per year vary widely from the mean and are not consistent. On the other hand, if the std is low, it means that the Total Bags sold per year are close to the mean and are consistent.*
#
# ##### *Therefore, by calculating the std of Total Bags sold per year for each type of avocado, we can determine if the sales have become more or less consistent over time. If the std decreases over time, it means that the sales are becoming more consistent. If the std increases over time, it means that the sales are becoming less consistent.*

# %%
#groups the data by year and type and calculates statard deviation of the total of bags
grouped_data = data.groupby(['year', 'type'])['Total Bags'].std().reset_index()

#pivot the data with years becoming the index and type becoming the columns
privoted_data = grouped_data.pivot(index="year", columns="type", values="Total Bags")

print(privoted_data.head())
print('The number of organic small bags sold are becoming more incosistent as the standard deviation is increasing')
print('The number of conventional were becoming more consistent from 2015 to 2017, however in 2018 they bacame more inconsistent again')
# Out:
# type  conventional        organic
# year
# 2015  7.518535e+05   25891.488427
# 2016  1.405738e+06   67562.728904
# 2017  1.549660e+06  105868.297187
# 2018  2.033493e+06  140777.215528
# The number of organic small bags sold are becoming more incosistent as the standard deviation is increasing
# The number of conventional were becoming more consistent from 2015 to 2017, however in 2018 they bacame more inconsistent again

# %% [markdown]
# ### C. Learn more
# * https://www.mathsisfun.com/data/standard-deviation.html
# * https://youtu.be/s7WTQ0H0Acc
